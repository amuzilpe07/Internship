# %% [markdown]
# ## PROJECT 1

# %% [raw]
# Red Wine Quality Prediction Project
# Project Description
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
# Attribute Information
# Input variables (based on physicochemical tests):
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)
# What might be an interesting thing to do, is to set an arbitrary cutoff for your dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# This allows you to practice with hyper parameter tuning on e.g. decision tree algorithms looking at the ROC curve and the AUC value.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Wine_Quality.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# In this dataset citric acid column having 0.00 value occurs 132 times

# %%
data.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1231            7.8             0.815         0.01             2.6      0.074
# 1590            6.3             0.550         0.15             1.8      0.077
# 582            11.7             0.490         0.49             2.2      0.083
# 1258            6.8             0.640         0.00             2.7      0.123
# 342            10.9             0.390         0.47             1.8      0.118
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1231                 48.0                  90.0  0.99621  3.38       0.62
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 582                   5.0                  15.0  1.00000  3.19       0.43
# 1258                 15.0                  33.0  0.99538  3.44       0.63
# 342                   6.0                  14.0  0.99820  3.30       0.75
#
#       alcohol  quality
# 1231     10.8        5
# ...

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
# According to the dataset Citric acid column having null data 132 times so i am replacing with mean
mean_value = data.loc[data['citric acid'] != 0, 'citric acid'].mean()
data['citric acid'] = data['citric acid'].replace(0,mean_value)

# %%
data['citric acid'].value_counts() # So its fill with average
# Out:
# citric acid
# 0.295358    132
# 0.490000     68
# 0.240000     51
# 0.020000     50
# 0.260000     38
#            ...
# 0.720000      1
# 0.620000      1
# 0.750000      1
# 1.000000      1
# 0.780000      1
# Name: count, Length: 80, dtype: int64

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.isnull().sum() # No null values are present
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.295358        2.538806
# std         1.741096          0.179060     0.177021        1.409928
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.100000          0.390000     0.150000        1.900000
# 50%         7.900000          0.520000     0.295358        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 1. it shows that mean is greater than the median that means some columns has right skewness is present
# 2. And observes that max and 75% difference is also huge in some columns so it has outliers are present

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(4,4))
sns.catplot(x='quality',data=data,kind='count')
plt.show()

# %% [markdown]
# Mejority of abservation is belongs to for quality 5 and 6

# %%
# Visualising barplot for analysing independent and dependent var
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['fixed acidity'])
plt.xlabel('Quality')
plt.ylabel('Fixed Acidity')
# Out:
# Text(0, 0.5, 'Fixed Acidity')

# %% [markdown]
# FA does not make any difference to the quality

# %%
# Visualising distplot

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['volatile acidity'])
plt.xlabel('Quality')
plt.ylabel('volatile acidity')
# Out:
# Text(0, 0.5, 'volatile acidity')

# %% [markdown]
# Volatile acidity are inversly proportional

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['citric acid'])
plt.xlabel('Quality')
plt.ylabel('citric acid')
# Out:
# Text(0, 0.5, 'citric acid')

# %% [markdown]
# citric acid does not make any difference to the quality

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['residual sugar'])
plt.xlabel('Quality')
plt.ylabel('residual sugar')
# Out:
# Text(0, 0.5, 'residual sugar')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['chlorides'])
plt.xlabel('Quality')
plt.ylabel('chlorides')
# Out:
# Text(0, 0.5, 'chlorides')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['free sulfur dioxide'])
plt.xlabel('Quality')
plt.ylabel('free sulfur dioxide')
# Out:
# Text(0, 0.5, 'free sulfur dioxide')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['total sulfur dioxide'])
plt.xlabel('Quality')
plt.ylabel('total sulfur dioxide')
# Out:
# Text(0, 0.5, 'total sulfur dioxide')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['density'])
plt.xlabel('Quality')
plt.ylabel('density')
# Out:
# Text(0, 0.5, 'density')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['pH'])
plt.xlabel('Quality')
plt.ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# pH does not make any difference to the quality

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['sulphates'])
plt.xlabel('Quality')
plt.ylabel('sulphates')
# Out:
# Text(0, 0.5, 'sulphates')

# %%
plt.figure(figsize=(4,4))
plt.bar(data['quality'],data['alcohol'])
plt.xlabel('Quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %% [markdown]
# Higher content of Alcohol improves the quality of wine

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.295358        2.538806
# std         1.741096          0.179060     0.177021        1.409928
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.100000          0.390000     0.150000        1.900000
# 50%         7.900000          0.520000     0.295358        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(26,24))
number_of_col = 1
for col in data:
    if number_of_col <=12:
        ax = plt.subplot(4,4,number_of_col)
        sns.distplot(data[col],color='c')
        plt.xlabel(col,fontsize=16)
    number_of_col+=1
plt.show()

# %% [markdown]
# skewness is there

# %%
plt.figure(figsize=(20,16))
number_of_col = 1
for col in data:
    if number_of_col <=12:
        plt.subplot(3,4,number_of_col)
        sns.boxplot(y=col, data=data, palette = 'coolwarm')
    number_of_col+=1
plt.show()

# %% [markdown]
# present outliers here.

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.634530
# volatile acidity          -0.256131          1.000000    -0.481498
# citric acid                0.634530         -0.481498     1.000000
# residual sugar             0.114777          0.001918     0.128656
# chlorides                  0.093705          0.061298     0.212303
# free sulfur dioxide       -0.153794         -0.010504    -0.074638
# total sulfur dioxide      -0.113181          0.076470    -0.021483
# density                    0.668047          0.022026     0.341003
# pH                        -0.682978          0.234937    -0.466802
# sulphates                  0.183006         -0.260987     0.300663
# alcohol                   -0.061668         -0.202288     0.135312
# quality                    0.124052         -0.390558     0.210381
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),fmt='0.1g',annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# here multicollinearity are present......so we handle multicollinearity by using variance inflation factor

# %%
data['quality'] = [1 if x>=7 else 0 for x in data['quality']]
data['quality'].value_counts()
# Out:
# quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %% [markdown]
# # Separate the Variables

# %%
x=data.drop("quality",axis=1)
y=data["quality"]

# %% [markdown]
# # Using Scalling Method

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877     0.000000       -0.453218  -0.243707
# 1         -0.298547          1.967442     0.000000        0.043416   0.223875
# 2         -0.298547          1.297065    -1.442982       -0.169427   0.096353
# 3          1.654856         -1.384443     1.495446       -0.453218  -0.264960
# 4         -0.528360          0.961877     0.000000       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -1.216949       -0.382271   0.053845
# 1595      -1.390155          0.123905    -1.103933       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.934408       -0.169427  -0.243707
# 1597      -1.390155          0.654620    -0.990916       -0.382271  -0.264960
# 1598      -1.332702         -1.216849     0.986872        0.752894  -0.434990
#
# ...

# %% [markdown]
# # Finding Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

VIF = pd.DataFrame()
VIF["vif values"] = [ variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
VIF["features"] = x.columns
VIF
# Out:
#     vif values              features
# 0     7.721199         fixed acidity
# 1     1.537861      volatile acidity
# 2     2.377519           citric acid
# 3     1.702767        residual sugar
# 4     1.483865             chlorides
# 5     1.930779   free sulfur dioxide
# 6     2.083723  total sulfur dioxide
# 7     6.345171               density
# 8     3.332548                    pH
# 9     1.430299             sulphates
# 10    3.013459               alcohol

# %% [markdown]
# find multicollinearity problem by using VIF .... here fixed acidity and density are correlation with other feature

# %% [markdown]
# here we drop those feature

# %%
x.drop("fixed acidity",axis = 1,inplace=True)

# %%
x.drop("density",axis = 1,inplace=True)

# %%
VIF = pd.DataFrame()
VIF["vif values"] = [ variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
VIF["features"] = x.columns
VIF
# Out:
#    vif values              features
# 0    1.474954      volatile acidity
# 1    1.746695           citric acid
# 2    1.088371        residual sugar
# 3    1.374922             chlorides
# 4    1.913626   free sulfur dioxide
# 5    1.972656  total sulfur dioxide
# 6    1.471636                    pH
# 7    1.334689             sulphates
# 8    1.280984               alcohol

# %% [markdown]
# MULTICOLLINEARITY ISSUE IS SOLVED

# %%
y.value_counts()
# Out:
# quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %% [markdown]
# Imbalance Dataset ...... uneven distribution
# To handle this ---- by using oversampling tech

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x1,y1 = sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %%
y1.value_counts()
# Out:
# quality
# 0    1382
# 1    1382
# Name: count, dtype: int64

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve

# %%
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=50)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.915625
# [[280   7]
#  [ 20  13]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       287
#            1       0.65      0.39      0.49        33
#
#     accuracy                           0.92       320
#    macro avg       0.79      0.68      0.72       320
# weighted avg       0.90      0.92      0.91       320

# %%
rfc = RandomForestClassifier()
rfc
# Out:
# RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=dtc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.9125
# [[271  16]
#  [ 12  21]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       287
#            1       0.57      0.64      0.60        33
#
#     accuracy                           0.91       320
#    macro avg       0.76      0.79      0.78       320
# weighted avg       0.92      0.91      0.91       320

# %%
etc=ExtraTreesClassifier()
etc
# Out:
# ExtraTreesClassifier()

# %%
etc.fit(x_train,y_train)
etc.score(x_train,y_train)
predetc=dtc.predict(x_test)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.9125
# [[271  16]
#  [ 12  21]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       287
#            1       0.57      0.64      0.60        33
#
#     accuracy                           0.91       320
#    macro avg       0.76      0.79      0.78       320
# weighted avg       0.92      0.91      0.91       320

# %%
dtc=DecisionTreeClassifier()
dtc
# Out:
# DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.91875
# [[273  14]
#  [ 12  21]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       287
#            1       0.60      0.64      0.62        33
#
#     accuracy                           0.92       320
#    macro avg       0.78      0.79      0.79       320
# weighted avg       0.92      0.92      0.92       320

# %%
gnb=GaussianNB()
gnb
# Out:
# GaussianNB()

# %%
gnb.fit(x_train,y_train)
gnb.score(x_train,y_train)
predgnb=gnb.predict(x_test)
print(accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# 0.89375
# [[263  24]
#  [ 10  23]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       287
#            1       0.49      0.70      0.57        33
#
#     accuracy                           0.89       320
#    macro avg       0.73      0.81      0.76       320
# weighted avg       0.91      0.89      0.90       320

# %%
svc=SVC()
svc
# Out:
# SVC()

# %%
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.934375
# [[286   1]
#  [ 20  13]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       287
#            1       0.93      0.39      0.55        33
#
#     accuracy                           0.93       320
#    macro avg       0.93      0.70      0.76       320
# weighted avg       0.93      0.93      0.92       320

# %% [markdown]
# Our Best Model is SVC

# %% [markdown]
# Conclusion - Higher Alcohol content improves the Quality of Wine
