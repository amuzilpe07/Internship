# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/refs/heads/main/Grades.csv ')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.sample(5)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 320  CS-97321      D     D+      D         C      C      D      B      D
# 137  CS-97138     C-     C+     WU        WU     WU      B     WU     WU
# 517  CS-97518     B+     C-      A        A-      A      A      A     B+
# 256  CS-97257     B-     C-      B        B-     C-     A-     C+     B+
# 226  CS-97227      A      A      A        A+     A-     A+      A     A-
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 320      D  ...      A      C      C     B-     B+      A     A-      B
# 137     A-  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 517      A  ...      A      C      A     B+      B     B-     B+     B-
# 256     B-  ...     C-      C     B-     C-      A     A-     C-     C+
# 226     A-  ...     B-     A-      A     B+      A      A      A      A
#
#     CS-412   CGPA
# 320    NaN  2.266
# 137    NaN  2.653
# 517      B  3.272
# ...

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.shape
# Out:
# (571, 43)

# %%
df['PH-121'].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
# Using for loop to see all the grades
for column in df.columns[1:-1]:
    print(df[column].unique())
# Out:
# ['B-' 'A' 'D' 'A-' 'B+' 'B' 'C+' 'C' 'C-' 'D+' 'WU' 'A+' 'F']
# ['D+' 'D' 'B' 'C+' 'A-' 'B-' 'C-' 'B+' 'C' 'A' 'A+' 'F']
# ['C-' 'D+' 'A' 'A-' 'B' 'C+' 'B+' 'B-' 'C' 'D' nan 'WU' 'A+' 'F']
# ['C' 'D' 'B-' 'B+' 'D+' 'B' 'C-' 'C+' 'A-' 'A' nan 'WU' 'A+' 'F']
# ['C-' 'B-' 'B+' 'D' 'A' 'C+' 'A-' 'C' 'B' 'D+' nan 'A+' 'F' 'WU']
# ['D+' 'C' 'A' 'A-' 'B' 'B-' 'B+' 'C+' 'C-' 'A+' 'D']
# ['D' 'B-' 'D+' 'A-' 'C+' 'A' 'C-' 'C' 'B' 'B+' nan 'A+' 'F' 'WU']
# ['C-' 'A' 'B+' 'B' 'A-' 'B-' 'C' 'C+' 'D+' 'D' nan 'A+' 'WU' 'F']
# ['B-' 'D+' 'A-' 'D' 'A' 'B+' 'B' 'C-' 'C+' 'C' 'WU' nan 'A+']
# ['C-' 'D' 'A-' 'C+' 'B+' 'A' 'D+' 'C' 'B' 'B-' 'WU' nan 'F' 'A+']
# ['C-' 'B+' 'B-' 'D' 'C' 'A-' 'C+' 'D+' 'B' 'A' nan 'A+' 'I' 'WU' 'F']
# ['B+' 'C+' 'A-' 'B' 'A' 'B-' nan 'D' 'WU' 'A+' 'C' 'D+' 'C-' 'F']
# ['D' 'B-' 'A' 'D+' 'C' 'B+' 'A-' 'B' 'C+' nan 'C-' 'WU' 'F' 'A+' 'W']
# ['A-' 'C-' 'A' 'B-' 'B+' 'C+' 'D+' 'B' nan 'C' 'W' 'A+' 'D' 'F']
# ...

# %%
# Convert Alphabets into Integers
# Put the values in grades higher to lower ( In descending order )
# Replace grades here

replace_grades = {'A+':15, 'A':14, 'A-':13, 'B+':12, 'B':11, 'B-':10, 'C+':9, 'C':8,'C-':7, 'D+':6,'D':5,'F':4,'W':3,'WU':2,'I':1}
df.replace(replace_grades,inplace=True)

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001      10       6     7.0        8.0     7.0       6     5.0
# 1    CS-97002      14       5     6.0        5.0    10.0       8     5.0
# 2    CS-97003      14      11    14.0       10.0    12.0      14    10.0
# 3    CS-97004       5       9     6.0        5.0     5.0      13     6.0
# 4    CS-97005      13      13    13.0       12.0    14.0      14    13.0
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567      11      14    14.0       13.0    15.0      14    13.0
# 567  CS-97568      15      14    14.0       14.0    14.0      14    14.0
# 568  CS-97569      11      14    13.0       12.0    14.0      14    14.0
# 569  CS-97570      14      12     5.0       14.0     5.0       6    10.0
# 570  CS-97571       8       5     5.0        8.0     8.0       6    11.0
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Null values are present 
# Fill nan values with mode here
for column in df.columns[1:-1]:
    df[column].fillna(df[column].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    int64
#  2   HS-101     571 non-null    int64
#  3   CY-105     571 non-null    float64
#  4   HS-105/12  571 non-null    float64
#  5   MT-111     571 non-null    float64
#  6   CS-105     571 non-null    int64
#  7   CS-106     571 non-null    float64
#  8   EL-102     571 non-null    float64
#  9   EE-119     571 non-null    float64
#  10  ME-107     571 non-null    float64
#  11  CS-107     571 non-null    float64
#  12  HS-205/20  571 non-null    float64
#  13  MT-222     571 non-null    float64
#  14  EE-222     571 non-null    float64
#  15  MT-224     571 non-null    float64
#  16  CS-210     571 non-null    float64
#  17  CS-211     571 non-null    float64
#  18  CS-203     571 non-null    float64
# ...

# %%
df.set_index('Seat No.', inplace=True)

# %%
df
# Out:
#           PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# Seat No.
# CS-97001      10       6     7.0        8.0     7.0       6     5.0     7.0
# CS-97002      14       5     6.0        5.0    10.0       8     5.0    14.0
# CS-97003      14      11    14.0       10.0    12.0      14    10.0    12.0
# CS-97004       5       9     6.0        5.0     5.0      13     6.0     7.0
# CS-97005      13      13    13.0       12.0    14.0      14    13.0    12.0
# ...          ...     ...     ...        ...     ...     ...     ...     ...
# CS-97567      11      14    14.0       13.0    15.0      14    13.0    13.0
# CS-97568      15      14    14.0       14.0    14.0      14    14.0    13.0
# CS-97569      11      14    13.0       12.0    14.0      14    14.0    14.0
# CS-97570      14      12     5.0       14.0     5.0       6    10.0     7.0
# CS-97571       8       5     5.0        8.0     8.0       6    11.0     9.0
#
# ...

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean    11.024518    9.809107   11.807356   10.644483   10.971979   11.994746
# std      2.957493    2.724223    2.825575    3.116687    2.857907    2.500872
# min      2.000000    4.000000    2.000000    2.000000    2.000000    5.000000
# 25%      9.000000    8.000000   10.500000    8.000000    9.000000   11.000000
# 50%     12.000000   10.000000   13.000000   11.000000   12.000000   13.000000
# 75%     13.000000   12.000000   14.000000   13.000000   13.000000   14.000000
# max     15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean    10.840630   10.924694   11.021016   10.073555  ...   11.005254
# ...

# %% [markdown]
# ## separate the variables

# %%
x=df.drop(columns='CGPA',axis=1)
y=df['CGPA']

# %%
y
# Out:
# Seat No.
# CS-97001    2.205
# CS-97002    2.008
# CS-97003    3.608
# CS-97004    1.906
# CS-97005    3.448
#             ...
# CS-97567    3.798
# CS-97568    3.772
# CS-97569    3.470
# CS-97570    2.193
# CS-97571    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
#Apply pca to reduce the columns
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca
# Out:
# PCA(n_components=10)

# %%
x = pca.fit_transform(x)
x.shape
# Out:
# (571, 10)

# %%
df.shape
# Out:
# (571, 42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
x=scaler.fit_transform(x)

# %%
x=pd.DataFrame(data=x)
x
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.408494 -0.401799  1.757951  0.805586  0.181195 -0.594169 -1.519347
# 1    1.654182 -0.790534  0.393786 -0.120749 -1.721864  0.445970 -0.905686
# 2   -1.039954 -0.522900  0.073154  1.561275  0.524291  1.003092 -0.105868
# 3    1.896814 -0.716489  0.648064  0.719675  0.151834  2.126701  1.479834
# 4   -0.781576 -0.870437  0.183827  1.108157 -0.491991 -1.009908 -0.844665
# ..        ...       ...       ...       ...       ...       ...       ...
# 566 -1.463950 -0.124979 -0.010489 -0.067636 -0.355994  1.251366  0.251312
# 567 -1.397250 -0.274873 -0.587898 -0.597526  0.563128  0.151383  2.172194
# 568 -0.813160  0.520316 -0.762544 -0.683177 -0.923302  0.172940  0.940089
# 569  1.159517 -0.312935 -0.916841 -1.435985  0.005350 -0.151391  0.247921
# 570  1.764967  0.225045 -1.575527  0.191016 -0.266285  0.961603 -1.675098
#
#             7         8         9
# 0   -0.683957  0.399695  0.294187
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca
# Out:
# PCA(n_components=10)

# %%
x = pca.fit_transform(x)
x.shape
# Out:
# (571, 10)

# %%
pd.DataFrame(data = x)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.820203 -0.909024  1.201761 -0.977209  0.047696 -1.494241 -0.062799
# 1    1.045038  0.208397 -0.818557  0.075456  1.790295 -0.877394 -0.758109
# 2   -0.228518 -1.254052  0.975286  1.361210 -0.328547 -0.464765 -0.072652
# 3    1.433305 -1.036011  1.512811  1.468174  0.170161  1.231885 -0.195135
# 4    0.724127 -0.663726  1.286218  0.104191 -1.522902 -1.371853 -0.855820
# ..        ...       ...       ...       ...       ...       ...       ...
# 566  0.677789  0.086359 -0.256488  0.565972  0.510841  0.572942 -0.478554
# 567  0.705992  0.366789 -0.352042  0.676099  0.051429  2.205274  0.744302
# 568  0.964288  0.634564 -1.425981 -0.028080  0.407270  0.739563  0.183938
# 569  0.078315  0.899593  0.448841  0.265858  0.659146  0.256430 -0.361447
# 570 -0.273883  1.108176 -1.329619  1.115117 -0.373676 -0.635627 -1.566338
#
#             7         8         9
# 0   -0.887161  1.408494 -0.620427
# ...

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
maxAccu = 0
maxRs = 0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=r2_score(y_test,predlr)
    if acc>maxAccu:
        maxAccu=acc
        maxRs = i
print("Max r2 score is ",maxAccu,"on Random State ",maxRs)
# Out:
# Max r2 score is  0.9763477571319336 on Random State  168

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRs)

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print(lr)
print('R2_Score: ',r2_score(y_test,predlr))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predlr))
print('Mean Squared Error: ',mean_squared_error(y_test,predlr))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# LinearRegression()
# R2_Score:  0.9763477571319336
# R2 Score on Training Data:  91.32092261149569
# Mean Absolutr Error:  0.07024885944106728
# Mean Squared Error:  0.008596818747243246
# Root Mean squared Error:  0.09271903120310979

# %%
rf = RandomForestRegressor()

rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
pred_train=rf.predict(x_train)
print(rf)
print('R2_Score: ',r2_score(y_test,predrf))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predrf))
print('Mean Squared Error: ',mean_squared_error(y_test,predrf))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# RandomForestRegressor()
# R2_Score:  0.9800784014124179
# R2 Score on Training Data:  98.29894364314006
# Mean Absolutr Error:  0.04904575581395357
# Mean Squared Error:  0.007240851244767455
# Root Mean squared Error:  0.08509319153003637

# %%
gbr = GradientBoostingRegressor()

gbr.fit(x_train,y_train)
predgbr=gbr.predict(x_test)
pred_train=gbr.predict(x_train)
print(gbr)
print('R2_Score: ',r2_score(y_test,predgbr))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predgbr))
print('Mean Squared Error: ',mean_squared_error(y_test,predgbr))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predgbr)))
# Out:
# GradientBoostingRegressor()
# R2_Score:  0.9745196792094599
# R2 Score on Training Data:  99.86637011703128
# Mean Absolutr Error:  0.04757969727396587
# Mean Squared Error:  0.009261265440227312
# Root Mean squared Error:  0.09623546872243784

# %%
dtr = DecisionTreeRegressor()

dtr.fit(x_train,y_train)
predtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print(dtr)
print('R2_Score: ',r2_score(y_test,predtr))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predtr))
print('Mean Squared Error: ',mean_squared_error(y_test,predtr))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predtr)))
# Out:
# DecisionTreeRegressor()
# R2_Score:  0.94829637423457
# R2 Score on Training Data:  100.0
# Mean Absolutr Error:  0.06363953488372094
# Mean Squared Error:  0.01879258139534884
# Root Mean squared Error:  0.13708603647107476

# %%
r = Ridge()

r.fit(x_train,y_train)
pred_r=r.predict(x_test)
pred_train=r.predict(x_train)
print(r)
print('R2_Score: ',r2_score(y_test,pred_r))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,pred_r))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_r))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,pred_r)))
# Out:
# Ridge()
# R2_Score:  0.9766401549386423
# R2 Score on Training Data:  91.32031311122064
# Mean Absolutr Error:  0.06986814671645611
# Mean Squared Error:  0.008490541682510391
# Root Mean squared Error:  0.09214413536688264

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=predlr,y=y_test,color='b')
plt.plot(predlr,predlr,color='green')
plt.xlabel("Actual",fontsize=16)
plt.ylabel("Predicted",fontsize=16)
plt.title("Linear Regression", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=predrf,y=y_test,color='b')
plt.plot(predrf,predrf,color='green')
plt.xlabel("Actual",fontsize=16)
plt.ylabel("Predicted",fontsize=16)
plt.title("Random Forest Regression", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=predtr,y=y_test,color='b')
plt.plot(predtr,predtr,color='g')
plt.xlabel("Actual",fontsize=16)
plt.ylabel("Predicted",fontsize=16)
plt.title("Decision Tree Regression", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=predgbr,y=y_test,color='b')
plt.plot(predgbr,predgbr,color='g')
plt.xlabel("Actual",fontsize=16)
plt.ylabel("Predicted",fontsize=16)
plt.title("Gradient Boosting Regressor", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=pred_r,y=y_test,color='b')
plt.plot(pred_r,pred_r,color='g')
plt.xlabel("Actual",fontsize=16)
plt.ylabel("Predicted",fontsize=16)
plt.title("Ridge Regression", fontsize=20)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(lr,x,y)
print(score1)
print(score1.mean())
print('Diff. between R2 score & CV score is -', r2_score(y_test,predlr)-score1.mean())
# Out:
# [0.90310903 0.94371371 0.93336471 0.95827625 0.85703212]
# 0.9190991643307317
# Diff. between R2 score & CV score is - 0.05724859280120187

# %%
score2 = cross_val_score(rf,x,y)
print(score2)
print(score2.mean())
print('Diff. between R2 score & CV score is -', r2_score(y_test,predrf)-score2.mean())
# Out:
# [0.86230268 0.9088716  0.93175977 0.97787693 0.851185  ]
# 0.9063991946020732
# Diff. between R2 score & CV score is - 0.07367920681034468

# %%
score3 = cross_val_score(gbr,x,y)
print(score3)
print(score3.mean())
print('Diff. between R2 score & CV score is -', r2_score(y_test,predgbr)-score3.mean())
# Out:
# [0.82260496 0.94922186 0.93802693 0.96178652 0.84720214]
# 0.9037684813346715
# Diff. between R2 score & CV score is - 0.07075119787478845

# %%
score4 = cross_val_score(dtr,x,y)
print(score4)
print(score4.mean())
print('Diff. between R2 score & CV score is -', r2_score(y_test,predtr)-score4.mean())
# Out:
# [0.69981836 0.87736535 0.93201176 0.88910196 0.84847211]
# 0.849353908217282
# Diff. between R2 score & CV score is - 0.09894246601728807

# %%
score5 = cross_val_score(r,x,y)
print(score5)
print(score5.mean())
print('Diff. between R2 score & CV score is -', r2_score(y_test,pred_r)-score5.mean())
# Out:
# [0.90358608 0.94382366 0.93324616 0.95856217 0.8567713 ]
# 0.9191978744761153
# Diff. between R2 score & CV score is - 0.05744228046252697

# %% [markdown]
# Ridge is our best model because Diff. between R2 score & CV score is

# %%
import joblib

# %%
joblib.dump(r,'Glass Identification Analysis.pkl') # Save in binary formate
# Out:
# ['Glass Identification Analysis.pkl']
