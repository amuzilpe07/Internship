# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv '
data = pd.read_csv(url)

# %%
df=pd.DataFrame(data=data)
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(5,5))
sns.histplot(df['Happiness Score'],kde=True)
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Region', y='Happiness Score', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### here we see that western europe, north american and aus n NZ regions countries are most happier according to the plot

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Family', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Economy (GDP per Capita)', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### highest Economy increases happiness score

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Health (Life Expectancy)', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Health (Life Expectancy) plays important role to define happiness score beacuse higher life expectancy increases the happiness

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Freedom', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### The more freedom people get , the happier they are

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Trust (Government Corruption)', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### The more curruption there is in regions, people are less happier

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Generosity', y='Happiness Score',hue='Region', data=df)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### generosity is not much impact on the Happiness Score

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Dystopia Residual', y='Happiness Score',hue='Region', data=data)
plt.title('Happiness Score by Region')
plt.xticks(rotation=45)
plt.show()

# %%
df.set_index('Country',inplace = True)

# %% [markdown]
# #### Apply label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
le.fit(df['Region'])
# Out:
# LabelEncoder()

# %%
df['Region']=le.transform(df['Region'])
df.head()
# Out:
#              Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland       9               1            7.587         0.03411
# Iceland           9               2            7.561         0.04884
# Denmark           9               3            7.527         0.03328
# Norway            9               4            7.522         0.03880
# Canada            5               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# ...

# %%
plt.figure(figsize=(10,10))
col = 1
for i in df:
    if col<= 10:
        plt.subplot(5,2,col)
        sns.regplot(x='Happiness Score', y=i, data=df, color = 'b')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
    col+=1
plt.show()

# %% [raw]
# According to the data GDP, Health and family would be useful predictors for happiness, those plots are linear.
# Features having positive linear relationships with happiness score.

# %%
df.corr()
# Out:
#                                  Region  Happiness Rank  Happiness Score  \
# Region                         1.000000        0.213773        -0.176791
# Happiness Rank                 0.213773        1.000000        -0.992105
# Happiness Score               -0.176791       -0.992105         1.000000
# Standard Error                -0.022600        0.158516        -0.177254
# Economy (GDP per Capita)      -0.260139       -0.785267         0.780966
# Family                        -0.168533       -0.733644         0.740605
# Health (Life Expectancy)      -0.357508       -0.735613         0.724200
# Freedom                        0.092567       -0.556886         0.568211
# Trust (Government Corruption)  0.165040       -0.372315         0.395199
# Generosity                     0.273557       -0.160142         0.180319
# Dystopia Residual             -0.057276       -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# ...

# %% [markdown]
# ##### Heatmap using iloc function to find correlation of specific column

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.iloc[:,[2,3,4,5,6,7,8,9,10]].corr(), annot=True, cmap='coolwarm')  # Show correlation heatmap
# Out:
# <Axes: >

# %% [raw]
# Economy,Family,Health is positive correlated with Happiness Score

# %% [markdown]
# ##### Find out Outliers

# %%
plt.figure(figsize=(12,8))
columns = 1
for i in df:
    if columns <= 11:
        plt.subplot(3,4,columns)
        sns.boxplot(df[i])
        plt.xlabel(i)
    columns+=1
plt.show()

# %% [raw]
# Outliers are present here

# %%
df.drop(columns=['Region','Standard Error','Happiness Rank','Generosity','Trust (Government Corruption)'],inplace=True,axis=1)

# %%
df
# Out:
#              Happiness Score  Economy (GDP per Capita)   Family  \
# Country
# Switzerland            7.587                   1.39651  1.34951
# Iceland                7.561                   1.30232  1.40223
# Denmark                7.527                   1.32548  1.36058
# Norway                 7.522                   1.45900  1.33095
# Canada                 7.427                   1.32629  1.32261
# ...                      ...                       ...      ...
# Rwanda                 3.465                   0.22208  0.77370
# Benin                  3.340                   0.28665  0.35386
# Syria                  3.006                   0.66320  0.47489
# Burundi                2.905                   0.01530  0.41587
# Togo                   2.839                   0.20868  0.13995
#
#              Health (Life Expectancy)  Freedom  Dystopia Residual
# Country
# Switzerland                   0.94143  0.66557            2.51738
# ...

# %% [markdown]
# ##### Separate Variables

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
x
# Out:
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
# ...                               ...      ...                       ...
# Rwanda                        0.22208  0.77370                   0.42864
# Benin                         0.28665  0.35386                   0.31910
# Syria                         0.66320  0.47489                   0.72193
# Burundi                       0.01530  0.41587                   0.22396
# Togo                          0.20868  0.13995                   0.28443
#
#              Freedom  Dystopia Residual
# Country
# ...

# %%
y
# Out:
# Country
# Switzerland    7.587
# Iceland        7.561
# Denmark        7.527
# Norway         7.522
# Canada         7.427
#                ...
# Rwanda         3.465
# Benin          3.340
# Syria          3.006
# Burundi        2.905
# Togo           2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
# ##### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# 3                    1.525130  1.251922                  1.035145  1.605131
# 4                    1.194876  1.221204                  1.118054  1.360416
# ..                        ...       ...                       ...       ...
# 153                 -1.552987 -0.800520                 -0.818610  1.087740
# 154                 -1.392303 -2.346860                 -1.263362  0.372033
# 155                 -0.455245 -1.901086                  0.372199 -1.809238
# 156                 -2.067566 -2.118467                 -1.649648 -2.064472
# 157                 -1.586334 -3.134725                 -1.404129 -0.426621
#
#      Dystopia Residual
# 0             0.758258
# ...

# %% [markdown]
# #### Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ##### Finding Best random state

# %%
maxAccu = 0
maxRs = 0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=r2_score(y_test,predlr)
    if acc>maxAccu:
        maxAccu=acc
        maxRs = i
print("Max r2 score is ",maxAccu,"on Random State ",maxRs)
# Out:
# Max r2 score is  0.9893526046133814 on Random State  234

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=maxRs)

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print(lr)
print('R2_Score: ',r2_score(y_test,predlr))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predlr))
print('Mean Squared Error: ',mean_squared_error(y_test,predlr))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# LinearRegression()
# R2_Score:  0.9893526046133814
# R2 Score on Training Data:  97.69535725668771
# Mean Absolutr Error:  0.10225325159688857
# Mean Squared Error:  0.014361771864491075
# Root Mean squared Error:  0.11984061024749113

# %%
gb = GradientBoostingRegressor()

gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
pred_train=gb.predict(x_train)
print(gb)
print('R2_Score: ',r2_score(y_test,predgb))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predgb))
print('Mean Squared Error: ',mean_squared_error(y_test,predgb))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predgb)))
# Out:
# GradientBoostingRegressor()
# R2_Score:  0.9415101114541642
# R2 Score on Training Data:  99.84923925950994
# Mean Absolutr Error:  0.23083549328226968
# Mean Squared Error:  0.07889426523321529
# Root Mean squared Error:  0.28088122976307134

# %%
rf = RandomForestRegressor()

rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
pred_train=rf.predict(x_train)
print(rf)
print('R2_Score: ',r2_score(y_test,predrf))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predrf))
print('Mean Squared Error: ',mean_squared_error(y_test,predrf))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# RandomForestRegressor()
# R2_Score:  0.9167601417087908
# R2 Score on Training Data:  98.90973973950882
# Mean Absolutr Error:  0.2585821874999996
# Mean Squared Error:  0.11227833769687459
# Root Mean squared Error:  0.3350795990460693

# %%
dt = DecisionTreeRegressor()

dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
pred_train=dt.predict(x_train)
print(dt)
print('R2_Score: ',r2_score(y_test,preddt))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,preddt))
print('Mean Squared Error: ',mean_squared_error(y_test,preddt))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,preddt)))
# Out:
# DecisionTreeRegressor()
# R2_Score:  0.9148548147859141
# R2 Score on Training Data:  100.0
# Mean Absolutr Error:  0.28903124999999996
# Mean Squared Error:  0.11484834374999991
# Root Mean squared Error:  0.33889282044622887

# %%
l = Lasso()

l.fit(x_train,y_train)
predl=l.predict(x_test)
pred_train=l.predict(x_train)
print(l)
print('R2_Score: ',r2_score(y_test,predl))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predl))
print('Mean Squared Error: ',mean_squared_error(y_test,predl))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predl)))
# Out:
# Lasso()
# R2_Score:  -0.014955577113624718
# R2 Score on Training Data:  0.0
# Mean Absolutr Error:  0.98065625
# Mean Squared Error:  1.3690259375
# Root Mean squared Error:  1.1700538182066669

# %%
ri = Ridge()

ri.fit(x_train,y_train)
predri=ri.predict(x_test)
pred_train=ri.predict(x_train)
print(ri)
print('R2_Score: ',r2_score(y_test,predri))
print('R2 Score on Training Data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolutr Error: ',mean_absolute_error(y_test,predri))
print('Mean Squared Error: ',mean_squared_error(y_test,predri))
print('Root Mean squared Error: ',np.sqrt(mean_squared_error(y_test,predri)))
# Out:
# Ridge()
# R2_Score:  0.9892049203644158
# R2 Score on Training Data:  97.6932436320709
# Mean Absolutr Error:  0.1028394418474905
# Mean Squared Error:  0.01456097621584709
# Root Mean squared Error:  0.12066887011921132

# %% [markdown]
# ##### Conclusion- Our Best Model is Linear Regression

# %% [raw]
# ##### The more freedom people get , the happier they are. Health (Life Expectancy) plays important role to define happiness score beacuse higher life expectancy increases the happiness, highest Economy increases happiness score, here we see that western europe, north american and aus n NZ regions countries are most happier than other regions, freedom, Health, Economy plays important role to make people happy thats those coutries happiness score is very good

# %% [markdown]
# ##### Saving The Model

# %%
import joblib
joblib.dump(lr, 'World_Happiness_Report_Analysis.pkl')
# Out:
# ['World_Happiness_Report_Analysis.pkl']
